# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np

# %%
df = pd.read_csv("../data/20230327_182001/DRL/Epi_1_run_1.csv")
# df = pd.read_csv("../data/20230327_182001/DRL/Trainer_Data.csv")

# %%
df.tail(10)
# Out:
#      Unnamed: 0                              long_wallet  episode  \
# 146         146  [array([0.1]), array([25936.63168416])]        1
# 147         147  [array([0.1]), array([25936.63168416])]        1
# 148         148  [array([0.1]), array([25936.63168416])]        1
# 149         149  [array([0.1]), array([25936.63168416])]        1
# 150         150                               [0.0, 0.0]        1
# 151         151                               [0.0, 0.0]        1
# 152         152                               [0.0, 0.0]        1
# 153         153                               [0.0, 0.0]        1
# 154         154                               [0.0, 0.0]        1
# 155         155                               [0.0, 0.0]        1
#
#      long_position      money   done  short_position          reward  \
# 146           0.49  [2593.66]  False             0.0  [[0.04520605]]
# 147           0.49  [2593.66]  False             0.0   [[0.0537239]]
# ...

# %%
plt.plot(df["wallet_value"].values[145:160])

# %%
plt.plot(df["btc_eur"])

# %%
plt.plot(df["long_position"])

# %%
plt.plot(df["btc_price"].values[145:160])
